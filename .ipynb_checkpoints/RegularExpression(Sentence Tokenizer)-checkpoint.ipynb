# %%
import re
import pandas as pd
import numpy as np

# %%
Answers = []

# %%
with open("Input", encoding='utf-8') as file:
    lines = (line.rstrip() for line in file)
    lines = list(line for line in lines if line)
    questions = list(filter(lambda line: re.search("[1-9].*\\?", line), lines))
    answer = ""
    for line in lines:
        if line not in questions:
            answer += line
        else:
            answer += '\n'
            Answers.append(answer)
            answer = ""
    
    answer += '\n'
    Answers.append(answer)

# %%
Answers = Answers[1:]
# Out:
# 'Answer: optional clauses for a block In Python.Python has its own method of implementing exception handling. is the block which can be used by the programmer to seethe error details without having to terminate the program. Also, in some cases, this statement offers a solution to deal withthe error.\n'

# %%
Df = pd.DataFrame(list(zip(questions,Answers)),columns=['Questions','Answers'])
Df.index = np.arange(1, len(Df)+1)

# %%
Df.to_csv("MyFinalOutput.csv")

# %%
Df
# Out:
#                                             Questions  \
# 1                     1. What is namespace in Python?
# 2   2. How do you make 3D plots/visualizations usi...
# 3        3. Differentiate between .py and .pyc files?
# 4                  4. What are Python's dictionaries?
# 5         5. How do | send mail from a Python script?
# 6   6. Why is that none of my threads are not runn...
# 7                   7. Explain about ODBC and Python?
# 8   8. Explain Python's pass by references Vs pass...
# 9          9. What is a module and package in Python?
# 10  10. How does exception handling in Python diff...
# 11                       11. Control flow statements?
# 12                               12. What is a Tuple?
# 13  13. How can you Get the Google cache age of an...
# 14                14. What is map function in Python?
# 15  15. What is Anonymous Function or Lambda Funct...
# 16                          16. Modules Search Path??
# 17      17. What is the function of a negative index?
# 18                18. What is the function of “self”?
# 19  19. What are the steps required to make a scri...
# 20                        20. What are the Packages??
# 21                         21. What is File Handling?
# 22  22. When would you use a break statement in a ...
# 23
# 23. How To Save An Image Locally Using Python...
# 24  24. What is the process to run sub-process wit...
# 25  25. What are the different ways to generate ra...
# 26  26. What Are The Built-In Types Available In P...
# 27  27. Which methods of Python are used to determ...
# 28      28. What is the use of enumerate() in Python?
# 29  29. How many kinds of sequences are supported ...
# 30  30. Name a few methods for matching and search...
# 31  31. Explain how Python does Compile-time and R...
# 32                  32. What is Abnormal Termination?
# 33                             33. What is Try Block?
# 34                            34. What is scheduling?
# 35                    35. What is Threads Life Cycle?
# 36  36. What is Web Scraping? How do you achieve i...
# 37       37. What are Accessors, mutators, @property?
# 38  38. How To Find Bugs Or Perform Static Analysi...
# 39
# 39. How to retrieve data from a table in MySQ...
# 40  40. What Are Different Methods To Copy An Obje...
# 41             41. When Is The Python Decorator Used?
# 42  42. What Is The Key Difference Between A List ...
# 43  43. What Is The Purpose Of Doc Strings In Python?
# 44                               44. What is Tkinter?
# 45  45. Name and explain the three magic methods o...
# 46  46. Which Python Function Will You Use To Conv...
# 47  47. How Do You Debug A Program In Python? Is I...
# 48  48. List Down Some Of The PDB Commands For Deb...
# 49  49. Why And When Do You Use Generators In Python?
# 50  50. Explain split(), sub(), sub() methods of “...
# 51  51. How can you generate random numbers in Pyt...
# 52  52. What advantages do NumPy arrays offer over...
# 53  53. What does this mean: *args, **kwargs? And ...
#
#                                               Answers
# 1   Answer: Like 2D plotting, 3D graphics is beyon...
# 2   Answer: Both .py and .pyc files hold the byte ...
# 3   Answer: Python's dictionaries are kind of hash...
# 4   Answer: Use the standard library module smtpli...
# 5   Answer: As soon as the main thread exits, all ...
# 6   Answer: ODBC (“Open Database Connectivity) API...
# 7   Answer: In Python, by default, all the paramet...
# 8   Answer: The module is the way to structure a p...
# 9   Answer: optional clauses for a block In Python...
# 10  Answer: By default, python program execution s...
# 11  Answer:1. Tuple Objects can be created by usin...
# 12  Answer:Use the following URL format:
# Be sure t...
# 13  Answer: map function executes the function giv...
# 14  Answer:A function which doesn’t contain any na...
# 15  Answer: By default python interpreter search f...
# 16  Answer: The sequences in python are indexed an...
# 17  Answer: “Self” is a variable that represents t...
# 18  Answer: The steps that are required to make a ...
# 19  Answer: The package is nothing but a folder or...
# 20  Answer: The file is a named location on the di...
# 21  Answer: The break statement states that the fu...
# 22  Answer: We will use the following code to save...
# 23  Answer: The popen2() module is used to run the...
# 24  Answer: The random module is the standard modu...
# 25  Answer: Here is the list of most commonly used...
# 26  Answer:Python has 2 built-in functions that wo...
# 27  Answer: Using enumerate() function you can ite...
# 28  Answer: Python supports 7 sequence types. They...
# 29  Answer: There are 4 different methods in the “...
# 30  Answer: Python performs some amount of compile...
# 31  Answer: The concept of terminating the program...
# 32  Answer: A block which is preceded by the try k...
# 33  Answer: Among multiple threads which thread as...
# 34  Answer: Threads Life CycleCreating the object ...
# 35  Answer: Web Scrapping is a way of extracting t...
# 36  Answer: Accessors and mutators are often calle...
# 37  Answer: You can use PyChecker, which is a stat...
# 38  Answer:Explain.import MySQLdb module as import...
# 39  Answer:There are two ways to copy objects in P...
# 40  Answer: Python decorator is a relative change ...
# 41  Answer:List Vs Tuple.The major difference betw...
# 42  Answer: In Python, a documentation string is p...
# 43  Answer: Tkinter is a Python library. It is a t...
# 44  Answer: The 3 magic methods of Python that are...
# 45  Answer: For converting a number into a string,...
# 46  Answer: Yes, we can use the Python debugger ()...
# 47  Answer: Here are a few PDB commands to start d...
# 48  Answer: A generator in Python is a function wh...
# 49  Answer: To modify the strings, Python's “re” m...
# 50  Answer: The random module is the standard modu...
# 51  Answer: Python's lists are efficient general-p...
# 52  Answer: We use *args when we aren't sure how m...
# 53  Answer: Python uses private heaps to maintain ...
